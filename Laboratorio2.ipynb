# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential 
from keras.layers import Dense
from sklearn.metrics import accuracy_score
#KFolds
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold



from sklearn.model_selection import GridSearchCV
from keras.layers import Activation
from keras.wrappers.scikit_learn import KerasClassifier
from keras.wrappers.scikit_learn import KerasRegressor

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
regr = linear_model.LinearRegression()

# %%
dataset = pd.read_csv("supermarket_sales.csv")
dataset.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
dataset.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
print(dataset["Payment"].unique())
# Out:
# ['Ewallet' 'Cash' 'Credit card']

# %%
ohe = pd.get_dummies(dataset['Gender'],drop_first = True)
dataset.drop('Gender', axis = 1, inplace = True)
dataset =  dataset.join(ohe)
dataset.head()
# Out:
#     Invoice ID Branch       City Customer type            Product line  \
# 0  750-67-8428      A     Yangon        Member       Health and beauty
# 1  226-31-3081      C  Naypyitaw        Normal  Electronic accessories
# 2  631-41-3108      A     Yangon        Normal      Home and lifestyle
# 3  123-19-1176      A     Yangon        Member       Health and beauty
# 4  373-73-7910      A     Yangon        Normal       Sports and travel
#
#    Unit price  Quantity   Tax 5%     Total       Date   Time      Payment  \
# 0       74.69         7  26.1415  548.9715   1/5/2019  13:08      Ewallet
# 1       15.28         5   3.8200   80.2200   3/8/2019  10:29         Cash
# 2       46.33         7  16.2155  340.5255   3/3/2019  13:23  Credit card
# 3       58.22         8  23.2880  489.0480  1/27/2019  20:33      Ewallet
# 4       86.31         7  30.2085  634.3785   2/8/2019  10:37      Ewallet
#
#      cogs  gross margin percentage  gross income  Rating  Male
# ...

# %%
ohe = pd.get_dummies(dataset['Customer type'],drop_first = True)
dataset.drop('Customer type', axis = 1, inplace = True)
dataset =  dataset.join(ohe)
dataset.head()
# Out:
#     Invoice ID Branch       City            Product line  Unit price  \
# 0  750-67-8428      A     Yangon       Health and beauty       74.69
# 1  226-31-3081      C  Naypyitaw  Electronic accessories       15.28
# 2  631-41-3108      A     Yangon      Home and lifestyle       46.33
# 3  123-19-1176      A     Yangon       Health and beauty       58.22
# 4  373-73-7910      A     Yangon       Sports and travel       86.31
#
#    Quantity   Tax 5%     Total       Date   Time      Payment    cogs  \
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet  522.83
# 1         5   3.8200   80.2200   3/8/2019  10:29         Cash   76.40
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating  Male  Normal
# 0                 4.761905       26.1415     9.1     0       0
# ...

# %%
ohe = pd.get_dummies(dataset['Branch'])
dataset.drop('Branch', axis = 1, inplace = True)
dataset =  dataset.join(ohe)
dataset.head()
# Out:
#     Invoice ID       City            Product line  Unit price  Quantity  \
# 0  750-67-8428     Yangon       Health and beauty       74.69         7
# 1  226-31-3081  Naypyitaw  Electronic accessories       15.28         5
# 2  631-41-3108     Yangon      Home and lifestyle       46.33         7
# 3  123-19-1176     Yangon       Health and beauty       58.22         8
# 4  373-73-7910     Yangon       Sports and travel       86.31         7
#
#     Tax 5%     Total       Date   Time      Payment    cogs  \
# 0  26.1415  548.9715   1/5/2019  13:08      Ewallet  522.83
# 1   3.8200   80.2200   3/8/2019  10:29         Cash   76.40
# 2  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31
# 3  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76
# 4  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17
#
#    gross margin percentage  gross income  Rating  Male  Normal  A  B  C
# 0                 4.761905       26.1415     9.1     0       0  1  0  0
# ...

# %%
ohe = pd.get_dummies(dataset['City'])
dataset.drop('City', axis = 1, inplace = True)
dataset =  dataset.join(ohe)
dataset.head()
# Out:
#     Invoice ID            Product line  Unit price  Quantity   Tax 5%  \
# 0  750-67-8428       Health and beauty       74.69         7  26.1415
# 1  226-31-3081  Electronic accessories       15.28         5   3.8200
# 2  631-41-3108      Home and lifestyle       46.33         7  16.2155
# 3  123-19-1176       Health and beauty       58.22         8  23.2880
# 4  373-73-7910       Sports and travel       86.31         7  30.2085
#
#       Total       Date   Time      Payment    cogs  ...  gross income  Rating  \
# 0  548.9715   1/5/2019  13:08      Ewallet  522.83  ...       26.1415     9.1
# 1   80.2200   3/8/2019  10:29         Cash   76.40  ...        3.8200     9.6
# 2  340.5255   3/3/2019  13:23  Credit card  324.31  ...       16.2155     7.4
# 3  489.0480  1/27/2019  20:33      Ewallet  465.76  ...       23.2880     8.4
# 4  634.3785   2/8/2019  10:37      Ewallet  604.17  ...       30.2085     5.3
#
#    Male  Normal  A  B  C  Mandalay  Naypyitaw  Yangon
# ...

# %%
ohe = pd.get_dummies(dataset['Product line'])
dataset.drop('Product line', axis = 1, inplace = True)
dataset =  dataset.join(ohe)
dataset.head()
# Out:
#     Invoice ID  Unit price  Quantity   Tax 5%     Total       Date   Time  \
# 0  750-67-8428       74.69         7  26.1415  548.9715   1/5/2019  13:08
# 1  226-31-3081       15.28         5   3.8200   80.2200   3/8/2019  10:29
# 2  631-41-3108       46.33         7  16.2155  340.5255   3/3/2019  13:23
# 3  123-19-1176       58.22         8  23.2880  489.0480  1/27/2019  20:33
# 4  373-73-7910       86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#        Payment    cogs  gross margin percentage  ...  C  Mandalay  Naypyitaw  \
# 0      Ewallet  522.83                 4.761905  ...  0         0          0
# 1         Cash   76.40                 4.761905  ...  1         0          1
# 2  Credit card  324.31                 4.761905  ...  0         0          0
# 3      Ewallet  465.76                 4.761905  ...  0         0          0
# 4      Ewallet  604.17                 4.761905  ...  0         0          0
#
# ...

# %%
ohe = pd.get_dummies(dataset['Payment'])
dataset.drop('Payment', axis = 1, inplace = True)
dataset =  dataset.join(ohe)
dataset.head()
# Out:
#     Invoice ID  Unit price  Quantity   Tax 5%     Total       Date   Time  \
# 0  750-67-8428       74.69         7  26.1415  548.9715   1/5/2019  13:08
# 1  226-31-3081       15.28         5   3.8200   80.2200   3/8/2019  10:29
# 2  631-41-3108       46.33         7  16.2155  340.5255   3/3/2019  13:23
# 3  123-19-1176       58.22         8  23.2880  489.0480  1/27/2019  20:33
# 4  373-73-7910       86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#      cogs  gross margin percentage  gross income  ...  Yangon  \
# 0  522.83                 4.761905       26.1415  ...       1
# 1   76.40                 4.761905        3.8200  ...       0
# 2  324.31                 4.761905       16.2155  ...       1
# 3  465.76                 4.761905       23.2880  ...       1
# 4  604.17                 4.761905       30.2085  ...       1
#
#    Electronic accessories  Fashion accessories  Food and beverages  \
# 0                       0                    0                   0
# ...

# %%
dataset.columns
# Out:
# Index(['Invoice ID', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'cogs', 'gross margin percentage', 'gross income', 'Rating',
#        'Male', 'Normal', 'A', 'B', 'C', 'Mandalay', 'Naypyitaw', 'Yangon',
#        'Electronic accessories', 'Fashion accessories', 'Food and beverages',
#        'Health and beauty', 'Home and lifestyle', 'Sports and travel', 'Cash',
#        'Credit card', 'Ewallet'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating         Male  \
# count             1.000000e+03   1000.000000  1000.00000  1000.000000
# mean              4.761905e+00     15.379369     6.97270     0.499000
# std               6.131498e-14     11.708825     1.71858     0.500249
# ...

# %%
#dataset = dataset[['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs', 'gross margin percentage', 'gross income', 'Rating','Male', 'A', 'B', 'C', 'Normal', 'Mandalay', 'Naypyitaw', 'Yangon','Electronic accessories', 'Fashion accessories', 'Food and beverages','Health and beauty', 'Home and lifestyle', 'Sports and travel', 'Cash','Credit card', 'Ewallet']]
dataset = dataset[['Unit price','cogs', 'Quantity','Male', 'A', 'B', 'C', 'Normal','Electronic accessories', 'Fashion accessories', 'Food and beverages','Health and beauty', 'Home and lifestyle', 'Sports and travel']]

# %%
y = dataset.loc[:,'Quantity']
x = dataset.iloc[:, dataset.columns != 'Quantity']

# %%
std_scaler = StandardScaler()

# %%
x = std_scaler.fit_transform(x)

# %%
x
# Out:
# array([[ 0.71816014,  0.91960685, -0.998002  , ...,  2.36197954,
#         -0.43643578, -0.44613985],
#        [-1.52530319, -0.98772956, -0.998002  , ..., -0.42337369,
#         -0.43643578, -0.44613985],
#        [-0.35278112,  0.07144605,  1.002002  , ..., -0.42337369,
#          2.29128785, -0.44613985],
#        ...,
#        [-0.89995809, -1.17810859,  1.002002  , ..., -0.42337369,
#         -0.43643578, -0.44613985],
#        [ 0.38320778, -1.03293176,  1.002002  , ..., -0.42337369,
#          2.29128785, -0.44613985],
#        [ 1.23361671,  1.32783657, -0.998002  , ..., -0.42337369,
#         -0.43643578, -0.44613985]])

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y ,test_size =0.2 ,random_state = 2022
                                                    , shuffle = True)

# %%
x_train.shape, y_train.shape
# Out:
# ((800, 13), (800,))

# %% [markdown]
# # Red 1

# %%
def red_v1 ():
    
    # base secuencial 
    clasificador = Sequential()

    #primera capa oculta

    clasificador.add(Dense(input_dim = 13, units = 6 , activation = 'relu', kernel_initializer = 'uniform'))
                 
    #segunda capa oculta
                 
    clasificador.add(Dense(units =6, activation ='relu', kernel_initializer ='uniform'))

    #capa de salida
                  
    clasificador.add(Dense(units=1, activation = 'sigmoid', kernel_initializer = 'uniform'))
    
    # parametros d eotpimizacion 

    clasificador.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])


    return clasificador

# %%
clasificador = KerasClassifier(build_fn = red_v1, batch_size = 25, nb_epoch =5100)

# %%
kfolds = KFold(n_splits =10, shuffle = True)

acc = cross_val_score(clasificador, X=x_train, y=y_train, cv = kfolds, verbose =1, n_jobs = -1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   10.2s finished

# %%
acc
# Out:
# array([0.0625    , 0.0875    , 0.1375    , 0.0875    , 0.075     ,
#        0.0875    , 0.075     , 0.075     , 0.0625    , 0.16249999])

# %%
acc.mean()
# Out:
# 0.0912500001490116

# %% [markdown]
# # RED 2

# %%
def red_v2 ():
    
    # base secuencial 
    clasificador = Sequential()

    #primera capa oculta

    clasificador.add(Dense(input_dim = 13, units = 6 , activation = 'relu', kernel_initializer = 'uniform'))
                 
    #segunda capa oculta
                 
    clasificador.add(Dense(units =6, activation ='relu', kernel_initializer ='uniform'))

    #capa de salida
                  
    clasificador.add(Dense(units=1, activation = 'sigmoid', kernel_initializer = 'uniform'))
    
    # parametros d eotpimizacion 

    clasificador.compile(optimizer = 'SGD', loss = 'binary_crossentropy', metrics = ['accuracy'])


    return clasificador

# %%
clasificador2 = KerasClassifier(build_fn = red_v2, batch_size = 25, nb_epoch =5100)

# %%
acc2 = cross_val_score(clasificador2, X=x_train, y=y_train, cv = kfolds, verbose =1, n_jobs = -1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    4.0s finished

# %%
acc2
# Out:
# array([0.1125    , 0.16249999, 0.0875    , 0.075     , 0.0875    ,
#        0.075     , 0.0125    , 0.125     , 0.0875    , 0.0875    ])

# %%
acc2.mean()
# Out:
# 0.09124999912455678

# %% [markdown]
# # RED 3

# %%
def red_v3 ():
    
    # base secuencial 
    clasificador = Sequential()

    #primera capa oculta

    clasificador.add(Dense(input_dim = 13, units = 6 , activation = 'relu', kernel_initializer = 'uniform'))
                 
    #segunda capa oculta
                 
    clasificador.add(Dense(units =6, activation ='relu', kernel_initializer ='uniform'))

    #capa de salida
                  
    clasificador.add(Dense(units=1, activation = 'sigmoid', kernel_initializer = 'uniform'))
    
    # parametros d eotpimizacion 

    clasificador.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])


    return clasificador

# %%
clasificador3 = KerasClassifier(build_fn = red_v3, batch_size = 25, nb_epoch =5100)

# %%
acc3 = cross_val_score(clasificador3, X=x_train, y=y_train, cv = kfolds, verbose =1, n_jobs = -1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.8s finished

# %%
acc3.mean()
# Out:
# 0.09125000201165676

# %% [markdown]
# # Red4

# %%
def red_v4 ():
    
    # base secuencial 
    clasificador = Sequential()

    #primera capa oculta

    clasificador.add(Dense(input_dim = 13, units = 6 , activation = 'relu', kernel_initializer = 'uniform'))
                 
    #segunda capa oculta
                 
    clasificador.add(Dense(units =6, activation ='relu', kernel_initializer ='uniform'))

    #capa de salida
                  
    clasificador.add(Dense(units=1, activation = 'sigmoid', kernel_initializer = 'uniform'))
    
    # parametros d eotpimizacion 

    clasificador.compile(optimizer = 'Adamax', loss = 'binary_crossentropy', metrics = ['accuracy'])


    return clasificador

# %%
clasificador4 = KerasClassifier(build_fn = red_v4, batch_size = 25, nb_epoch =5100)

# %%
acc4 = cross_val_score(clasificador4, X=x_train, y=y_train, cv = kfolds, verbose =1, n_jobs = -1)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    0.8s finished

# %%
acc4.mean()
# Out:
# 0.09125000163912773

# %% [markdown]
# # RED 5

# %%
# Creamos el objeto de Regresión Linear
regr = linear_model.LinearRegression()

# %%
# Entrenamos nuestro modelo
regr.fit(x_train, y_train)
 
# Hacemos las predicciones que en definitiva una línea (en este caso, al ser 2D)
y_pred = regr.predict(x_train)

# %%
estimacion_y = regr.predict(x_test)

# %%
#error absoluto de media

print("erro medio absoluto: %.2f"% np.mean(np.absolute(estimacion_y -y_test)))
# Out:
# erro medio absoluto: 0.79

# %%
# Error cuadrativo medio

print("erro cuadratico medio: %.2f"% np.mean((estimacion_y -y_test)**2))
# Out:
# erro cuadratico medio: 1.25

# %%
estimacion_y
# Out:
# array([10.21008209,  2.02551178,  5.11926178,  3.64855865,  9.05480865,
#         5.54113678,  4.90637115,  3.3087149 ,  7.6212149 ,  2.02062897,
#         0.86584381,  5.33459381,  2.96105865,  2.28723053,  6.55334381,
#         3.86779694,  4.82531647,  3.1993399 , 10.24230865,  6.96691803,
#         5.34582428,  2.57531647,  2.27941803,  5.66711334,  6.78332428,
#         3.07141022,  6.18615631, 11.19055084,  3.88879303,  4.45910553,
#         4.40930084,  6.70129303,  6.71887115,  8.93566803,  9.2540274 ,
#         6.76672272,  6.25256256,  0.36828522,  4.33410553,  4.89758209,
#         5.78918365,  4.30285553,  9.1055899 , 10.3868399 ,  6.9571524 ,
#         4.11975006,  4.3399649 ,  5.63586334,  5.74865631,  7.25646881,
#         7.60754303, 10.38098053,  8.71887115,  6.61730865, -0.12976166,
#         9.47668365,  5.67101959,  5.02600006,  6.00988678,  5.79894928,
#         4.59045319,  8.74426178,  8.8712149 ,  5.8712149 ,  5.37512115,
# ...

# %% [markdown]
# # Este fue el modelo elegido debido al arrer obtenido en cada en unas de las predicciones, se obtuvo una estimacion del 79%

# %%
print("Coeficientes:" , regr.coef_)
print("Intercepto:" , regr.intercept_)
# Out:
# Coeficientes: [-2.10658959e+00  3.38293448e+00 -3.01622175e-02 -2.59934022e+12
#  -2.58409796e+12 -2.57616252e+12 -3.34175160e-03 -7.35263221e+12
#  -7.48730019e+12 -7.42068477e+12 -7.02747090e+12 -7.17594283e+12
#  -7.28310221e+12]
# Intercepto: 5.518187561035156

# %% [markdown]
# # GRID SEARCH

# %%
# crear un diccionario con hiper parametros

parametros = {
    'batch_size': [5,8],
    'nb_epoch': [100,200],
    'optimizer': ['adam', 'SGD']
}

# %%
def grid_search_v1 (optimizer):
    clasificador = Sequential()
    clasificador.add(Dense(input_dim = 13, units = 6 , activation = 'relu', kernel_initializer = 'uniform'))
    clasificador.add(Dense(units =6, activation ='relu', kernel_initializer ='uniform'))
    clasificador.add(Dense(units=1, activation = 'sigmoid', kernel_initializer = 'uniform'))
    clasificador.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return clasificador

# %%
clasificador_grid_search = KerasClassifier(build_fn = grid_search_v1)

# %%
grid_out = GridSearchCV(estimator= clasificador_grid_search,
                     param_grid = parametros,
                     cv=20,
                     scoring = 'accuracy')

# %%
train_grid_out = grid_out.fit(x_train, y_train, verbose =1)
# Out:
# 152/152 [==============================] - 0s 319us/step - loss: 0.2923 - accuracy: 0.0947
# WARNING:tensorflow:From D:\Users\Jhonnatan\anaconda3\envs\Galileo_2022\lib\site-packages\tensorflow\python\keras\wrappers\scikit_learn.py:241: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# ...
# 160/160 [==============================] - 0s 408us/step - loss: -0.3837 - accuracy: 0.0913

# %%
#Guardar el modelo

#path = './'
#grid_out.save(path+ 'grid_search.h5')

# %%
#cargamos a la read 

#new_model = keras.models.load_model(path+ '6_6_sig_out.h5')

# %%
#predicciones

y_pred = grid_out.predict(x_test)
y_pred
# Out:
# array([[2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
#        [2],
# ...

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.09
